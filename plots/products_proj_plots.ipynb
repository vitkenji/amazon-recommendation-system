# %%
import networkx as nx

# %%
G = nx.read_gml('../network/products.gml')

# %%
G.number_of_edges()
# Out:
# 882239

# %%
G.number_of_nodes()
# Out:
# 3772

# %%
G.nodes[[n for n, d in G.nodes(data=True)][0]]
# Out:
# {'type': 'product',
#  'main_category': 'cell phones & accessories',
#  'average_rating': 4.5,
#  'rating_number': 7415.0,
#  'price': '49.95'}

# %%
u, v, data = list(G.edges(data=True))[0]
data
# Out:
# {}
