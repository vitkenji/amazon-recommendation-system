# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/subsample.csv')

# %%
df.head()
# Out:
#    rating parent_asin                       user_id         main_category  \
# 0       5  B0887P21Z2  AHGAOIZVODNHYMNCBV4DECZH42UQ             computers
# 1       5  B0BPN2DXC1  AHGAOIZVODNHYMNCBV4DECZH42UQ             computers
# 2       1  B09JKYBVJD  AHGAOIZVODNHYMNCBV4DECZH42UQ             computers
# 3       5  B008GVOVK0  AHGAOIZVODNHYMNCBV4DECZH42UQ  home audio & theater
# 4       5  B00TOVTZ7K  AHGAOIZVODNHYMNCBV4DECZH42UQ  home audio & theater
#
#    average_rating  rating_number  price   neg    neu    pos  compound
# 0             4.8        48733.0  76.48  0.08  0.764  0.156    0.4738
# 1             4.6        20671.0  54.98  0.00  1.000  0.000    0.0000
# 2             4.3         6168.0  85.99  0.00  0.859  0.141    0.6808
# 3             4.0        14281.0  10.49  0.00  0.891  0.109    0.8061
# 4             4.5        26636.0  18.79  0.00  0.280  0.720    0.8834

# %%
len(df)
# Out:
# 295218
